# %% [markdown]
# # S&P 500 Time Series Anomaly Detection
# This ML script uses Keras/Tensorflow as a backend for detecting anomalies (95% < outliers in MAE loss function) relative to other months in the S&P 500's close history.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
from sklearn.preprocessing import StandardScaler
from tensorflow import keras
import warnings
warnings.filterwarnings('ignore')


# %matplotlib inline
# %config InlineBackend.figure_format='retina'

register_matplotlib_converters()
sns.set(style='whitegrid', font_scale=1.25)
rcParams['figure.figsize'] = 16, 9

seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Data Preprocessing & EDA

# %%
df = pd.read_csv('./data/spx.csv', parse_dates=['date'], index_col='date')
df.head()
# Out:
#              close
# date
# 1986-01-02  209.59
# 1986-01-03  210.88
# 1986-01-06  210.65
# 1986-01-07  213.80
# 1986-01-08  207.97

# %%
plt.plot(df, label='close price')
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("Daily S&P 500 Close Price")
# Out:
# Text(0.5, 1.0, 'Daily S&P 500 Close Price')

# %%
train_size = int(len(df) * 0.95)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]
print(train.shape, test.shape)
# Out:
# (7782, 1) (410, 1)

# %%
scaler = StandardScaler()
scaler = scaler.fit(train[['close']])
train['close'] = scaler.transform(train[['close']])
test['close'] = scaler.transform(test[['close']])

# %%
def format_time_series_data(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)        
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
steps = 30
X_train, y_train = format_time_series_data(train[['close']], train.close, steps)
X_test, y_test = format_time_series_data(test[['close']], test.close, steps)
print(X_train.shape)
# Out:
# (7752, 30, 1)

# %% [markdown]
# ## LSTM Anomaly Detection: MAE

# %%
model = keras.Sequential()
model.add(keras.layers.LSTM(
    units=64, 
    input_shape=(X_train.shape[1], X_train.shape[2])
))
model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.RepeatVector(n=X_train.shape[1]))
model.add(keras.layers.LSTM(units=64, return_sequences=True))
model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.TimeDistributed(keras.layers.Dense(units=X_train.shape[2])))
model.compile(loss='mae', optimizer='adam')

# %%
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=16,
    validation_split=0.1,
    shuffle=False
)
# Out:
# Train on 6976 samples, validate on 776 samples
# Epoch 1/20
# 6976/6976 [==============================] - 7s 994us/sample - loss: 0.1212 - val_loss: 0.2784
# Epoch 2/20
# 6976/6976 [==============================] - 4s 644us/sample - loss: 0.0773 - val_loss: 0.2681
# Epoch 3/20
# 6976/6976 [==============================] - 4s 636us/sample - loss: 0.0786 - val_loss: 0.1195
# Epoch 4/20
# 6976/6976 [==============================] - 5s 647us/sample - loss: 0.0769 - val_loss: 0.2088
# Epoch 5/20
# 6976/6976 [==============================] - 4s 643us/sample - loss: 0.0757 - val_loss: 0.1640
# Epoch 6/20
# 6976/6976 [==============================] - 5s 646us/sample - loss: 0.0738 - val_loss: 0.2119
# Epoch 7/20
# 6976/6976 [==============================] - 4s 642us/sample - loss: 0.0730 - val_loss: 0.1741
# Epoch 8/20
# 6976/6976 [==============================] - 5s 657us/sample - loss: 0.0726 - val_loss: 0.1553
# Epoch 9/20
# 6976/6976 [==============================] - 5s 655us/sample - loss: 0.0705 - val_loss: 0.1985
# Epoch 10/20
# 6976/6976 [==============================] - 5s 655us/sample - loss: 0.0688 - val_loss: 0.1980
# Epoch 11/20
# 6976/6976 [==============================] - 5s 655us/sample - loss: 0.0706 - val_loss: 0.2085
# Epoch 12/20
# 6976/6976 [==============================] - 4s 632us/sample - loss: 0.0704 - val_loss: 0.2560
# Epoch 13/20
# 6976/6976 [==============================] - 4s 632us/sample - loss: 0.0703 - val_loss: 0.2403
# Epoch 14/20
# 6976/6976 [==============================] - 4s 628us/sample - loss: 0.0695 - val_loss: 0.2561
# Epoch 15/20
# 6976/6976 [==============================] - 4s 640us/sample - loss: 0.0696 - val_loss: 0.2013
# Epoch 16/20
# 6976/6976 [==============================] - 4s 633us/sample - loss: 0.0671 - val_loss: 0.2290
# Epoch 17/20
# 6976/6976 [==============================] - 4s 644us/sample - loss: 0.0680 - val_loss: 0.2506
# Epoch 18/20
# 6976/6976 [==============================] - 4s 630us/sample - loss: 0.0669 - val_loss: 0.2243
# Epoch 19/20
# 6976/6976 [==============================] - 4s 630us/sample - loss: 0.0671 - val_loss: 0.2393
# Epoch 20/20
# 6976/6976 [==============================] - 4s 627us/sample - loss: 0.0681 - val_loss: 0.2450

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()

# %%
X_train_pred = model.predict(X_train)
train_mae_loss = np.mean(np.abs(X_train_pred - X_train), axis=1)

# %%
sns.distplot(train_mae_loss, bins=50, kde=True);

# %%
X_test_pred = model.predict(X_test)

test_mae_loss = np.mean(np.abs(X_test_pred - X_test), axis=1)

# %%
anomaly_thresold = 0.95
test_score_df = pd.DataFrame(index=test[steps:].index)
test_score_df['loss'] = test_mae_loss
test_score_df['threshold'] = anomaly_thresold
test_score_df['anomaly'] = test_score_df.loss > test_score_df.threshold
test_score_df['close'] = test[steps:].close

# %%
plt.plot(test_score_df.index, test_score_df.loss, label='loss')
plt.plot(test_score_df.index, test_score_df.threshold, label='threshold')
plt.legend()

# %%
anomalies = test_score_df[test_score_df.anomaly == True]
anomalies.head()
# Out:
#                 loss  threshold  anomaly     close
# date
# 2018-01-30  0.961556       0.95     True  3.432543
# 2018-01-31  0.995410       0.95     True  3.435135
# 2018-02-01  1.008632       0.95     True  3.431698
# 2018-02-02  1.016783       0.95     True  3.319282
# 2018-02-05  1.058944       0.95     True  3.106679

# %%
plt.plot(
  test[steps:].index,
  scaler.inverse_transform(test[steps:].close),
  label='close price'
);

sns.scatterplot(
  anomalies.index,
  scaler.inverse_transform(anomalies.close),
  color=sns.color_palette()[3],
  s=52,
  label='anomaly'
)
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.title("Daily S&P 500 Close Price") 
plt.legend()
